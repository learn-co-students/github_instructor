# %%
from sklearn.datasets import load_diabetes
import pandas as pd
import numpy as np
import seaborn as sns

# %%
data = load_diabetes()

# %%
features = pd.DataFrame(data.data)
target = data.target

# %%
sns.pairplot(features.iloc[:,:5])
